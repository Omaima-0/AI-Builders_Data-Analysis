# %% [markdown]
# # Import Library: Pandas

# %%
import pandas as pd 
# print the version 
print(pd.__version__)
# Out:
# 3.0.6

# %% [markdown]
# # Datatype

# %% [markdown]
# ### Series: 1 dimensional column of data

# %%
cars = pd.Series(["BMW", "TOYOTA", "MARCEDES"])
cars
# Out:
# 0         BMW
# 1      TOYOTA
# 2    MARCEDES
# dtype: str

# %%
colors = pd.Series(["Blue", "Red", "Pink"])
colors
# Out:
# 0    Blue
# 1     Red
# 2    Pink
# dtype: str

# %% [markdown]
# ### Dataframe: row and column

# %%
car_data = pd.DataFrame({
    "Car type": cars,
    "Colors": colors
})
car_data
# Out:
#    Car type Colors
# 0       BMW   Blue
# 1    TOYOTA    Red
# 2  MARCEDES   Pink

# %%
Car_sales = pd.read_csv("../Pandas/Car_sales.csv")
Car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %% [markdown]
# ## Export data  (like if I changed something and I want to save it)

# %%
Car_sales.to_csv("../pandas/Car-sales-exported.csv")

# %% [markdown]
# ## Describe Data

# %% [markdown]
# 1- Exploring the data

# %%
# first check the data type for each column 
Car_sales.dtypes
# Out:
# Manufacturer               str
# Model                      str
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type               str
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# dtype: object

# %%
# gives statistical overreveiw on numercal column (all numbers)
Car_sales.describe()
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width
# count   156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000
# std       1.044653   56.700321    7.641303    3.451872
# min       1.000000   55.000000   92.600000   62.600000
# 25%       2.300000  149.500000  103.000000   68.400000
# ...

# %%
#info: show how many entries and columns I have, and nulls, and the datatype for each column (full overview) 
Car_sales.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    str
#  1   Model                157 non-null    str
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    str
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
# dtypes: float64(7), str(3)
# memory usage: 12.4 KB

# %%
#doing mathematical fourms on the numeric data 
Car_sales.mean(numeric_only=True)
# Out:
# Sales_in_thousands      52.998076
# __year_resale_value     18.072975
# Price_in_thousands      27.390755
# Engine_size              3.060897
# Horsepower             185.948718
# Wheelbase              107.487179
# Width                   71.150000
# dtype: float64

# %%
car_prices = pd.Series([10000, 3000, 77000])
car_prices.mean(numeric_only=True)
# Out:
# np.float64(30000.0)

# %%
Car_sales.sum(numeric_only=True)
# Out:
# Sales_in_thousands      8320.698
# __year_resale_value     2186.830
# Price_in_thousands      4245.567
# Engine_size              477.500
# Horsepower             29008.000
# Wheelbase              16768.000
# Width                  11099.400
# dtype: float64

# %% [markdown]
# # Viewing and Selecting Data

# %%
Car_sales.head()  # it's ganna show the first 5 columns from up, or put specific number in ()
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width
# 0               21.50          1.8       140.0      101.2   67.3
# 1               28.40          3.2       225.0      108.1   70.3
# 2                 NaN          3.2       225.0      106.9   70.6
# 3               42.00          3.5       210.0      114.6   71.4
# 4               23.99          1.8       150.0      102.6   68.2

# %%
Car_sales.tail()  # show the last 5 columns
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width
# 152                24.4          1.9       160.0      100.5   67.6
# 153                27.5          2.4       168.0      104.9   69.3
# 154                28.8          2.4       168.0      104.9   69.3
# 155                45.5          2.3       236.0      104.9   71.5
# 156                36.0          2.9       201.0      109.9   72.1

# %%
# .loc -> takes the index and it will bring the item
animals = pd.Series(["dog", "cat", "Hourse", "snake", " elephent"],
                    index = [44,55,22,11,33]) # this change the index number
animals
# Out:
# 44          dog
# 55          cat
# 22       Hourse
# 11        snake
# 33     elephent
# dtype: str

# %%
animals.loc[11]  # it based on the lebal that I costmized
# Out:
# 'snake'

# %%
animals.iloc[3] # it works only with their real indecies not the costmized ones
# Out:
# 'snake'

# %%
Car_sales.loc[4]
# Out:
# Manufacturer                Audi
# Model                         A4
# Sales_in_thousands        20.397
# __year_resale_value       22.255
# Vehicle_type           Passenger
# Price_in_thousands         23.99
# Engine_size                  1.8
# Horsepower                 150.0
# Wheelbase                  102.6
# Width                       68.2
# Name: 4, dtype: object

# %%
Car_sales["Horsepower"]  #access by the put the entry name
# Out:
# 0      140.0
# 1      225.0
# 2      225.0
# 3      210.0
# 4      150.0
#        ...
# 152    160.0
# 153    168.0
# 154    168.0
# 155    236.0
# 156    201.0
# Name: Horsepower, Length: 157, dtype: float64

# %%
#Boolean indexing 
Car_sales[Car_sales["Horsepower"] > 200]
# Out:
#     Manufacturer           Model  Sales_in_thousands  __year_resale_value  \
# 1          Acura              TL              39.384               19.875
# 2          Acura              CL              14.114               18.225
# 3          Acura              RL               8.588               29.725
# 6           Audi              A8               1.380               39.000
# 11         Buick           Regal              39.350               13.740
# 12         Buick     Park Avenue              27.851               20.190
# 13         Buick         LeSabre              83.257               13.360
# 14      Cadillac         DeVille              63.729               22.525
# 15      Cadillac         Seville              15.943               27.100
# 16      Cadillac        Eldorado               6.536               25.725
# 18      Cadillac        Escalade              14.785                  NaN
# 24     Chevrolet        Corvette              17.947               36.225
# ...

# %%
Car_sales[Car_sales["Model"] == "C70"] #all data that have C70
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 155        Volvo   C70               3.493                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width
# 155                45.5          2.3       236.0      104.9   71.5

# %%
#Compare two different Coulmns 
pd.crosstab(Car_sales["Model"], Car_sales["Vehicle_type"])
# Out:
# Vehicle_type  Car  Passenger
# Model
# 3-Sep           0          1
# 3000GT          0          1
# 300M            0          1
# 323i            0          1
# 328i            0          1
# ...           ...        ...
# Viper           0          1
# Voyager         1          0
# Windstar        1          0
# Wrangler        1          0
# Xterra          1          0
#
# [156 rows x 2 columns]

# %%
Car_sales.groupby("Model").mean(numeric_only=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 Car_sales.groupby("Model").mean(numeric_only=True)
#
# NameError: name 'Car_sales' is not defined

# %%
Car_sales.info
# Out:
# <bound method DataFrame.info of     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %% [markdown]
# ## Manipulating Data

# %%
Car_sales["Manufacturer"].str.lower()  # I can make it lower()
# Out:
# 0      acura
# 1      acura
# 2      acura
# 3      acura
# 4       audi
#        ...
# 152    volvo
# 153    volvo
# 154    volvo
# 155    volvo
# 156    volvo
# Name: Manufacturer, Length: 157, dtype: str

# %%
Car_sales
# Out:
#     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          Acura  Integra              16.919               16.360
# 1          Acura       TL              39.384               19.875
# 2          Acura       CL              14.114               18.225
# 3          Acura       RL               8.588               29.725
# 4           Audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        Volvo      V40               3.545                  NaN
# 153        Volvo      S70              15.245                  NaN
# 154        Volvo      V70              17.531                  NaN
# 155        Volvo      C70               3.493                  NaN
# 156        Volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 0      Passenger               21.50          1.8       140.0      101.2
# ...

# %%
Car_sales["Manufacturer"] = Car_sales["Manufacturer"].str.lower()
Car_sales.head
# Out:
# <bound method NDFrame.head of     Manufacturer    Model  Sales_in_thousands  __year_resale_value  \
# 0          acura  Integra              16.919               16.360
# 1          acura       TL              39.384               19.875
# 2          acura       CL              14.114               18.225
# 3          acura       RL               8.588               29.725
# 4           audi       A4              20.397               22.255
# ..           ...      ...                 ...                  ...
# 152        volvo      V40               3.545                  NaN
# 153        volvo      S70              15.245                  NaN
# 154        volvo      V70              17.531                  NaN
# 155        volvo      C70               3.493                  NaN
# 156        volvo      S80              18.969                  NaN
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# ...

# %%
missing_car_df= pd.read_csv("../Pandas/car-sales-missing-data.csv")
missing_car_df
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %% [markdown]
# we have to fill the NAN

# %%
# by using:fillna
missing_car_df["Odometer"].fillna(missing_car_df["Odometer"].mean(), inplace = False)
# Out:
# 0    150043.000000
# 1     87899.000000
# 2     92302.666667
# 3     11179.000000
# 4    213095.000000
# 5     92302.666667
# 6     92302.666667
# 7     92302.666667
# 8     60000.000000
# 9     31600.000000
# Name: Odometer, dtype: float64

# %%
missing_car_df   # but still no change becuse the inplace= False, and not assigned
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
missing_car_df ["Odometer"] = missing_car_df ["Odometer"].fillna(missing_car_df["Odometer"].mean(), inplace = True)
# Out:
# C:\Users\Omaima\AppData\Local\Temp\ipykernel_21028\1893338551.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   missing_car_df ["Odometer"] = missing_car_df ["Odometer"].fillna(missing_car_df["Odometer"].mean(), inplace = True)

# %%
missing_car_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
#Dropping the NaN 
missing_car_df.dropna()
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
missing_car_df
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
missing_car_df.dropna(inplace=True)  # using inplace=True to change it from the table 
missing_car_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  ENgine size
# 0  Toyota  White  150043.000000    4.0   $4,000      5         1.30
# 1   Honda    Red   87899.000000    4.0   $5,000      5         2.40
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5         3.60
# 3     BMW  Black   11179.000000    5.0  $22,000      5         4.88
# 4  Nissan  White  213095.000000    4.0   $3,500      5         7.44
# 5  Toyota  Green   92302.666667    4.0   $4,500      5         1.00

# %%
#Adding extra coloumn
seats_column = pd.Series([5,5,5,5,5,5])
missing_car_df["Seats"] = seats_column
missing_car_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats
# 0  Toyota  White  150043.000000    4.0   $4,000      5
# 1   Honda    Red   87899.000000    4.0   $5,000      5
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5
# 3     BMW  Black   11179.000000    5.0  $22,000      5
# 4  Nissan  White  213095.000000    4.0   $3,500      5
# 5  Toyota  Green   92302.666667    4.0   $4,500      5

# %%
engine_size = [1.3,2.4,3.6,4.88,7.44,1.00]
missing_car_df["ENgine size"] = engine_size
missing_car_df
# Out:
#      Make Colour       Odometer  Doors    Price  Seats  ENgine size
# 0  Toyota  White  150043.000000    4.0   $4,000      5         1.30
# 1   Honda    Red   87899.000000    4.0   $5,000      5         2.40
# 2  Toyota   Blue   92302.666667    3.0   $7,000      5         3.60
# 3     BMW  Black   11179.000000    5.0  $22,000      5         4.88
# 4  Nissan  White  213095.000000    4.0   $3,500      5         7.44
# 5  Toyota  Green   92302.666667    4.0   $4,500      5         1.00

# %%
# how to drop specific coloumn
car_sales = car_sales.drop("Price", axis=1) 
car_sales
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # how to drop specific coloumn
# ----> 2 car_sales = car_sales.drop("Price", axis=1)
#       3 car_sales
#
# NameError: name 'car_sales' is not defined

# %%
# sample: print suffled data from the table
car_sales_samples = car_sales_samples(frac=0)
car_sales_samples
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # sample: print suffled data from the table
# ----> 2 car_sales_samples = car_sales_samples(frac=0)
#       3 car_sales_samples
#
# NameError: name 'car_sales_samples' is not defined

# %%
# reset the indeces:
car_sales_samples.reset.index(
    car_Sales_Samples
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 # reset the indeces:
# ----> 2 car_sales_samples.reset.index(
#       3     car_Sales_Samples
#       4 )
#
# NameError: name 'car_sales_samples' is not defined

# %%
#TO CONVERT FROM KM TO MILES
car_sales["Odemetor"] = car_sales["Odemetor"].apply(lambda x: x/1.6   )
